# %% [markdown]
# # Question 1
#
# ## a)

# %%
r=0
for n in range(200):
  if n%5==1:
    r=10*0.9**(n-1)+r

# %%
r
# Out:
# 24.41942807976587

# %% [markdown]
# ## b)

# %% [markdown]
# r
# =10+0.9^5*10+0.9^10*10+...
# =10*（1+0.9^5+0.9^10+...）
# =10*sum((0.9^5)^k)
# =10/(1-0.9^5)

# %%
10/(1-0.9**5)
# Out:
# 24.419428096993972

# %% [markdown]
# So the result is the same with Q1 a)

# %% [markdown]
# ## c)
#
# The values v∗(s) = {22.0, 19.8, 17.8, 16.0, 14.4, 13.0} are all repeated multiple
# times.
# From the question, we can see that for each position, there's a  number of fewest steps to reach A, which can return the largest reward 10.

# %%
# For instance, for those positions which can reach A for one step, their v∗(s) =0.9*v∗(s = A) =0.9*24.4 
0.9*24.4 

#This value is close to 22
# Out:
# 21.96

# %%
# For those positions which can reach A for two step, their v∗(s) =0.9^2*v∗(s = A) =0.9^2*24.4 
0.9**2*24.4 

#This value is close to 19.8
# Out:
# 19.764

# %%
#For those positions which can reach A for three step, their v∗(s) =0.9^3*v∗(s = A) =0.9^3*24.4 
0.9**3*24.4 

#This value is close to 17.8
#Other values can be proved similarly.
# Out:
# 17.7876

# %% [markdown]
# # Question 2

# %% [markdown]
# ## a)

# %%
# install OpenAI gym per https://gym.openai.com/docs/
#!pip install gym
# see scratch_lec05 for all basics of q learning and cartpole in gym
import gym
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
env = gym.make('CartPole-v0')
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)

# %% [markdown]
# ## b)

# %%
from IPython.display import Image
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2df0bb66-b76f-4a9f-9775-f9100921cd69" name="files[]" multiple disabled />
#      <output id="result-2df0bb66-b76f-4a9f-9775-f9100921cd69">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving q2-b.PNG to q2-b.PNG

# %%
Image('q2-b.PNG',width = 1200)

# %% [markdown]
# # Question 3

# %% [markdown]
# a) List all team members: Chuqiao Rong (CR2945), Yumengmeng Xiao (YX2444), Yue Gao (YG2546), and Yiqiao Yin (YY2502).
#
# b) We are choosing Project 1 (CIFAR10) data set image classification dataset. The challenge for this data set is to design a machine learning or AI algorithm to classify all images into 10 classes (airplanes, automobiles, birds, cats, deer, dogs, frogs, horses, ships, and trucks).
#
# c) We are given 60,000 images into 10 classes. We will be using 48000 as training and 12000 as testing. Each image has 32x32 pixels and we process RGB channels for every image.
#
# d) There are a lot of existing approach. A starting point is to simply refer to LeCun Network that was successfully used in 10-class digit classification MNIST dataset. To implement this starter code, we use parameters: (1) epochs = 10, (2) batch_size = 128, (3) keep_probability = 0.7, (4) learning_rate = 0.001.
#
# e) For the above architecture, we have trained our neural network and we present some preliminary results:
#
# f) We are planning to do a lots of tuning using several laptops and conduct this procedure parallely. It is of our interest to change batch size, learning rate, and keep probability.
#
# g) We anticipate to raise accuracy. However, at this point, we do not have a specific value of for our expectation.

# %% [markdown]
# Below is for e)

# %%
from IPython.display import Image
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9a256321-73a4-4e32-8584-2c35c2b93534" name="files[]" multiple disabled />
#      <output id="result-9a256321-73a4-4e32-8584-2c35c2b93534">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving q3.PNG to q3.PNG

# %%
Image('q3.PNG',width = 1200)
